# %% [markdown]
# # Exploratory Data Analysis of California Housing Price Data Set (Assignment)

# %% [markdown]
# ## Learning Goals:
# - Demonstrate mastery of topics covered in the Boston Housing EDA tutorial
# - Use Pandas DataFrame
# - Use Seaborn to plot
#     - pair plots
#     - scatterplots
#     - heat map of correlation coefficients
#     - line of best fit and confidence interval

# %% [markdown]
# ## Instructor Notes:
# - This key includes code to produce figures and to answer questions
# - Give the assignment to students without the code except for the code in Task 12.
# - This assignment should follow the Boston Housing Data Exploratory Data Analysis Tutorial
# - The instructor will need to cover Pandas DataFrames and specific Seaborn functions prior to assigning this to students.

# %%
# import packages we will use
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn # to get the California data set
# %matplotlib inline

# %% [markdown]
# ### Import the Data Set from Sklearn.

# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing(as_frame=True)

# %% [markdown]
# ### Task 1: Make a list (using bullet points in Markdown) of the features in this data set and a description of what each feature is.

# %%
print(california_housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# ...

# %% [markdown]
# ### Task 2: Put the data into a Pandas DataFrame with the last column as the median house value.

# %%
df = pd.DataFrame(data=data.data, columns=data.feature_names)
df['MedHouseVal'] = data.target # add last column
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %% [markdown]
# ### Task 3: Describe the data.
# - How many samples are in this data set?
# - What are the minimum, maximum and mean median house value of the data set?
# - In the data set, what feature has the largest mean?  What is its mean?  What feature has the smallest mean?  What is its mean?  Are the far apart?
# - Do any variables take on negative values?  Explain.

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# ### Task 4: Plot the means of each feature as a bar plot.

# %%
df_desc = df.describe()

df_desc.loc['mean'].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Task 5: Are there any null values in the data set?

# %%
# this gives the total number of null values in each column
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %% [markdown]
# ### Task 6: Are there any duplicate values in the data set?

# %%
# check for duplicate entries
df.duplicated()
# if there are none, the sum of all will be zero
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Task 7: Loop through the various styles available and save the figures in a folder in your working directory called "plots."  Chose your favorite style and remake the mean bar plot.

# %%
pwd
# if this is not the working directory you want
# import os 
# os.chdir ('THIS SHOULD BE YOUR DESIRED DIRECTORY')
# loop through styles to choose what we prefer
# samples will be stored in a folder called "plots" in your working directory
for style in plt.style.available:
    plt.style.use(style)
    df.loc['mean'].plot.bar()
    plt.title(style) # so we know which one is which
    # we need to make a folder called plots in the directory we are working to save the figures
    plt.savefig('plots/' + style + ".png")
    
 # go to the folder to see which plot you like best

# %%
# let's say we like the ggplot version the best
plt.style.use('ggplot')
df_desc.loc['mean'].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Task 8: Use Seaborn to make pair plots.
# - Identify two variables which appear to be positively correlated.
# - Identify two variables which appear to be negatively correlated.
# - Looking at the histograms on the diagonal, do any appear to be bimodal?  If so, which?  Any hypothesis as to why that might be?

# %%
import seaborn as sns
sns.pairplot(df)  
# this will create 9 x 9 = 81 subplots

# %% [markdown]
# ### Task 9: We are interested in how price relates to the features in this data set.  Make scatter plots for each feature with price as the dependent variable, and the other features as independent variable (make a plot for each feature).
# - What observations can you make from these plots?

# %%
rows = 3
cols = 3
# we have 9 features total

fig, ax = plt.subplots(rows, cols, figsize = (10,10) ) 

col = df.columns
index = 0

# plot median house value as dependent variable (y-axis) against all other variables

for i in range(rows):
    for j in range(cols):
        sns.scatterplot(x = col[index], y = 'MedHouseVal', data = df, ax = ax[i][j]) 
        index = index + 1
        
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 10: Make a correlation matrix and a heatmap.
# - Comment on what features are highly correlated.

# %%
corrmat = df.corr() # make correlation matrix
corrmat # each entry gives Pearson correlation coefficient.
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
# size
corrmat.shape
# Out:
# (9, 9)

# %%
# plot as a heat map to visualize the information in the matrix
fig, ax = plt.subplots(figsize = (9, 9)) 
sns.heatmap(corrmat, annot = True, annot_kws = {'size': 7}) 
plt.show()

# %%
def getCorrelatedFeature(corrdata, threshold):
    feature = []
    value = [] # store correlation value for particular features
    
    for i, index in enumerate(corrdata.index):
        if abs(corrdata[index]) > threshold:
            feature.append(index)
            value.append(corrdata[index])
        
    df = pd.DataFrame(data = value, index = feature, columns = ['corr value'])
        
    return df

# %%
corrmat
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %% [markdown]
# ### Task 11: Which variables have an absolute correlation value greater than .1 when compared to MedHouseVal?

# %%
# set threshold
threshold = .1
# create data frame which has correlation values with price > threhold or < -threshold
corr_df = getCorrelatedFeature(corrmat['MedHouseVal'], threshold) # we are passing the price column only
corr_df
# Out:
#              corr value
# MedInc         0.688075
# HouseAge       0.105623
# AveRooms       0.151948
# Latitude      -0.144160
# MedHouseVal    1.000000

# %% [markdown]
# ### Task 12: Use the code given below to create an image depicting the median house value based on spatial location.
# - What do you notice?  Describe your observations.  Does anything in this figure relate to bimodality you noticed in a few histograms?  Explain.
# - Can you identify the location of the groups of yellow circles by looking at a map of California?  In this 1997 data set, how do prices in Humboldt compare qualitatively to the rest of the state?

# %%
import seaborn as sns

sns.scatterplot(data=df, x="Longitude", y="Latitude",
                size="MedHouseVal", hue="MedHouseVal",
                palette="viridis", alpha=0.5)
plt.legend(title="MedHouseVal", bbox_to_anchor=(1.05, 0.95),
           loc="upper left")
_ = plt.title("Median house value depending of\n their spatial location")

# %% [markdown]
# ## References
# - Pace, R. Kelley, and Ronald Barry. "Sparse spatial autoregressions." Statistics & Probability Letters 33.3 (1997): 291-297.
